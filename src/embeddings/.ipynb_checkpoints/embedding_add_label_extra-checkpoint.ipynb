# %%
import pandas as pd
import numpy as np

# %%
data = np.load("../../IMGVR/SkipGram_embedding_IMGVR_extra.npy")
df = pd.DataFrame(data)

print(df.shape)
# Out:
# (144192, 100)

# %%
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.007464  0.032135  0.023175  0.010819  0.044533 -0.029914 -0.008041
# 1 -0.079939 -0.557393 -0.733584 -0.020018 -0.381353 -1.625690  0.259802
# 2 -0.033577  0.020094 -0.028904  0.182547  0.354601 -0.344863  0.152129
# 3 -0.028377  0.294077  0.089067  0.058224 -0.251111 -0.380363  1.020436
# 4  1.125986  0.442871  0.356776  0.214696  0.249352 -0.200964  0.537971
#
#          7         8         9     ...           90        91        92  \
# 0 -0.035343  0.010872 -0.003333    ...     0.015318 -0.039715  0.009906
# 1 -0.640867 -0.020425  1.154452    ...     1.056579  0.577265  0.238010
# 2 -0.016344  0.021715 -0.040697    ...    -0.358476  0.469110  0.191624
# 3  0.283272 -0.256612  0.653677    ...     0.357485  0.115721  0.514390
# 4 -0.974916  0.259691  0.204189    ...    -0.068852 -1.159367 -0.222604
#
#          93        94        95        96        97        98        99
# ...

# %%
nodes = pd.read_csv("../data/transform/imgvr_extra/IMGVR_extra_KGX_nodes.tsv", sep="\t")
print(nodes.shape)
# Out:
# (144192, 4)

# %%
nodes.head()
# Out:
#                                                   id  \
# 0                                     vOTU:sg_502237
# 1  NCBItaxon:bacteria;proteobacteria;gammaproteob...
# 2                                    Contig_length:4
# 3                          Virus_topology:concatemer
# 4  NCBItaxon:monodnaviria;loebvirae;hofneiviricot...
#
#                                                 name               category  \
# 0                                          sg_502237              kbase:otu
# 1  bacteria;proteobacteria;gammaproteobacteria;ps...  biolink:OrganismTaxon
# 2                                                  4  biolink:QuantityValue
# 3                                         concatemer      biolink:Attribute
# 4  monodnaviria;loebvirae;hofneiviricota;faservir...  biolink:OrganismTaxon
#
#   provided_by
# 0        GOLD
# 1        GOLD
# 2        GOLD
# 3        GOLD
# 4        GOLD

# %%
df = df.set_index(nodes['id'])

# %%
df.to_csv("../../IMGVR/SkipGram_embedding_IMGVR_extra_wlabels.tsv", sep="\t")

# %%
dfnp = df.to_numpy()
np.save("../../IMGVR/SkipGram_embedding_IMGVR_extra_wlabels.npy", dfnp)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-ad1132fd2627> in <module>
# ----> 1 dfnp = df.to_numpy()
#       2 np.save("../../IMGVR/SkipGram_embedding_IMGVR_extra_wlabels.npy", dfnp)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'to_numpy'
